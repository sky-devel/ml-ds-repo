# %% [markdown]
# # Методы ML на основе деревьев решений

# %%
from sklearn.model_selection import train_test_split
from sklearn.datasets import load_iris
import pandas as pd
import seaborn as sns

# %%
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# #### Подготовка датасета

# %%
dataset = load_iris()
df = pd.DataFrame(dataset.data, columns=dataset.feature_names)
df["class"] = dataset.target
df["class_name"] = dataset.target_names[dataset["target"]]

x_train, x_test, y_trarin, y_test = train_test_split(
    dataset.data,
    dataset.target,
    test_size=0.2,
    random_state=42,
)

# %% [markdown]
# #### Парная диаграмма. Визуализация взаимосвязи в наборе данных

# %%
sns.pairplot(
    data=df,
    hue="class_name",
    diag_kind="hist",
)

# %% [markdown]
# ## Деревья решений

# %% [markdown]
# #### Обучение модели

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
model = DecisionTreeClassifier()
model.fit(x_train, y_trarin)
pass

# %% [markdown]
# #### Измерение точности

# %%
model.score(x_test, y_test)
# Out:
# 1.0

# %% [markdown]
# #### Получение предсказания

# %%
predict_class = model.predict([[4.9, 4.1, 1.3, 0.5]])[0]
print(f"Вид ириса: {dataset.target_names[predict_class]}")
# Out:
# Вид ириса: setosa

# %% [markdown]
# ## Случайные леса

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
model = RandomForestClassifier(
    n_estimators=244,
    max_depth=4
)
model.fit(x_train, y_trarin)
pass

# %% [markdown]
# #### Измерение точности

# %%
model.score(x_test, y_test)
# Out:
# 1.0

# %% [markdown]
# #### Получение предсказания

# %%
predict_class = model.predict([[4.9, 4.1, 1.3, 0.5]])[0]
print(f"Вид ириса: {dataset.target_names[predict_class]}")
# Out:
# Вид ириса: setosa
